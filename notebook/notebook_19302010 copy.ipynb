# %%
import pandas as pd 
import json
import os
import yaml
from pathlib import Path

# %%
def fct_load_config(config_filename: str = "config.yaml") -> dict:
    """
    Goal:
        Function to load configuration parameters from a YAML file.
    Parameters:
        config_filename (str): Relative or absolute path to the YAML file.
    Returns:
        dict: A dictionary containing the configuration parameters.
    """

    config_path = Path(config_filename)

    # Si le chemin est relatif, on le résout depuis la racine du projet
    if not config_path.is_absolute():
        project_root = Path(__file__).resolve().parents[1]
        config_path = project_root / config_path

    if not config_path.exists():
        raise FileNotFoundError(f"Config file not found: {config_path}")

    with open(config_path, "r", encoding="utf-8") as f:
        config = yaml.safe_load(f)

    return config

def fct_read_csv(root_file: str) -> pd.DataFrame:
    """
    Goal:
        Function to read a CSV file and return a pandas DataFrame.
    Parameters:
        root_file (str): Relative or absolute path to the CSV file.
    Returns:
        pd.DataFrame: The DataFrame containing the data from the CSV file.
    """
    seps = [',', ';', '|', '\t']

    file_path = Path(root_file)

    if not file_path.is_absolute():
        try:
            # Cas script Python
            project_root = Path(__file__).resolve().parents[1]
        except NameError:
            # Cas notebook Jupyter
            project_root = Path.cwd().parent

        file_path = project_root / file_path

    if not file_path.exists():
        print(f"Erreur : fichier {file_path} introuvable")
        return pd.DataFrame()

    for sep in seps:
        try:
            df = pd.read_csv(
                file_path,
                sep=sep,
                encoding="utf-8",
                skipinitialspace=True
            )

            # Si plus d'une colonne → bon séparateur
            if df.shape[1] > 1:
                return df

        except Exception:
            continue

    print(f"Aucun séparateur valide trouvé pour {file_path}")
    return pd.DataFrame()


def fct_read_json_nested(root_file: str) -> dict:
    """
    Goal
        Function to read a JSON file and return a pandas DataFrame.
    Parameters:
        root_file (str): The path to the JSON file.
    Returns:
        pd.DataFrame: The DataFrame containing the data from the JSON file.
    """
    with open(root_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    dfs = {}

    # --------------------
    # DIMENSIONS
    # --------------------
    dfs['stadiums'] = pd.DataFrame(data.get('stadiums', []))
    dfs['tvchannels'] = pd.DataFrame(data.get('tvchannels', []))
    dfs['teams'] = pd.DataFrame(data.get('teams', []))

    # --------------------
    # MATCHES - GROUP STAGE
    # --------------------
    matches = []

    for group_key, group_data in data.get('groups', {}).items():
        for match in group_data.get('matches', []):
            match_flat = match.copy()
            match_flat['group'] = group_key
            match_flat['stage'] = 'group'
            matches.append(match_flat)

    # --------------------
    # MATCHES - KNOCKOUT
    # --------------------
    for round_key, round_data in data.get('knockout', {}).items():
        for match in round_data.get('matches', []):
            match_flat = match.copy()
            match_flat['group'] = None
            match_flat['stage'] = round_key
            matches.append(match_flat)

    dfs['matches'] = pd.DataFrame(matches)

    return dfs



def fct_add_prefix_to_df(df:pd.DataFrame, prefix:str) -> pd.DataFrame:
    """
    Goal:
        Function to add a prefix to all column names in a DataFrame.
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        prefix (str): The prefix to add to each column name.
    Returns:
        pd.DataFrame: The DataFrame with updated column names.
    """
    for col in df.columns:
        df.rename(columns={col: f"{prefix}_{col}"}, inplace=True)
    return df



def fct_extract_data(
    root_csv_2010: str,
    root_csv_2014: str,
    root_csv_2022: str,
    root_json_2018: str
) -> None:
    """
    Goal:
        Function to extract data from a CSV files and JSON file to a consolidated DataFrame df.
    Parameters:
        root_csv_2010 (str): The path to the first CSV file.
        root_csv_2014 (str): The path to the second CSV file.
        root_csv_2022 (str): The path to the third CSV file.
        root_json_2018 (str): The path to the JSON file.
    Returns:
        pd.DataFrame: The consolidated DataFrame containing data from all files.
    """
    df_2010 = fct_read_csv(root_csv_2010)
    df_2014 = fct_read_csv(root_csv_2014)
    df_2022 = fct_read_csv(root_csv_2022)
    df_2018 = fct_read_json_nested(root_json_2018)
    
    print(df_2010.head())
    print(df_2014.head())
    print(df_2022.head())
    print(df_2018['matches'].head())
    # df = pd.concat([df_2010, df_2014, df_2022, df_2018], ignore_index=True)
    return None

# %%
# Load configuration parameters from config.yaml
config_path = os.path.join(Path.cwd().parent, 'config.yaml')
config = fct_load_config(config_path)

root_csv_2010 = config['root_csv_2010']
root_csv_2014 = config['root_csv_2014']
root_csv_2022 = config['root_csv_2022']
root_json_2018 = config['root_json_2018']       

# read data in dfs
df_2010 = fct_read_csv(root_csv_2010)
df_2014 = fct_read_csv(root_csv_2014)
df_2022 = fct_read_csv(root_csv_2022)

# %%
df_2010.head()
# Out:
#         edition        round      score                     team1  \
# 0  1930-URUGUAY  GROUP_STAGE  4-1 (3-0)                    France
# 1  1930-URUGUAY  GROUP_STAGE  3-0 (2-0)                       USA
# 2  1930-URUGUAY  GROUP_STAGE  2-1 (2-0)  Yugoslavia (Југославија)
# 3  1930-URUGUAY  GROUP_STAGE  3-1 (1-0)         Romania (România)
# 4  1930-URUGUAY  GROUP_STAGE  1-0 (0-0)                 Argentina
#
#               team2                             url        venue  year
# 0   Mexico (México)   1930_URUGUAY_FS.htm#1-WC-30-I  Montevideo.  1930
# 1  Belgium (België)  1930_URUGUAY_FS.htm#13-WC-30-I  Montevideo.  1930
# 2   Brazil (Brasil)   1930_URUGUAY_FS.htm#7-WC-30-I  Montevideo.  1930
# 3       Peru (Perú)  1930_URUGUAY_FS.htm#10-WC-30-I  Montevideo.  1930
# 4            France   1930_URUGUAY_FS.htm#2-WC-30-I  Montevideo.  1930

# %%
#remplir des valeurs vides 
df_2010 = df_2010.fillna(0)

# %%
score = df_2010['score']
score = score[:3]
df_2010.head()
# Out:
#         edition        round      score                     team1  \
# 0  1930-URUGUAY  GROUP_STAGE  4-1 (3-0)                    France
# 1  1930-URUGUAY  GROUP_STAGE  3-0 (2-0)                       USA
# 2  1930-URUGUAY  GROUP_STAGE  2-1 (2-0)  Yugoslavia (Југославија)
# 3  1930-URUGUAY  GROUP_STAGE  3-1 (1-0)         Romania (România)
# 4  1930-URUGUAY  GROUP_STAGE  1-0 (0-0)                 Argentina
#
#               team2                             url        venue  year
# 0   Mexico (México)   1930_URUGUAY_FS.htm#1-WC-30-I  Montevideo.  1930
# 1  Belgium (België)  1930_URUGUAY_FS.htm#13-WC-30-I  Montevideo.  1930
# 2   Brazil (Brasil)   1930_URUGUAY_FS.htm#7-WC-30-I  Montevideo.  1930
# 3       Peru (Perú)  1930_URUGUAY_FS.htm#10-WC-30-I  Montevideo.  1930
# 4            France   1930_URUGUAY_FS.htm#2-WC-30-I  Montevideo.  1930

# %%
import re

def extract_all_scores(text):
    if pd.isna(text):
        return []
    scores = re.findall(r"\d+\s*-\s*\d+", text)
    return [s.replace(" ", "") for s in scores]

df_2010["score_list"] = df_2010["score"].apply(extract_all_scores)
df_2010.head(n=50)
# Out:
#          edition                    round               score  \
# 0   1930-URUGUAY              GROUP_STAGE           4-1 (3-0)
# 1   1930-URUGUAY              GROUP_STAGE           3-0 (2-0)
# 2   1930-URUGUAY              GROUP_STAGE           2-1 (2-0)
# 3   1930-URUGUAY              GROUP_STAGE           3-1 (1-0)
# 4   1930-URUGUAY              GROUP_STAGE           1-0 (0-0)
# 5   1930-URUGUAY              GROUP_STAGE           3-0 (1-0)
# 6   1930-URUGUAY              GROUP_STAGE           4-0 (0-0)
# 7   1930-URUGUAY              GROUP_STAGE           3-0 (2-0)
# 8   1930-URUGUAY              GROUP_STAGE           1-0 (0-0)
# 9   1930-URUGUAY              GROUP_STAGE           1-0 (0-0)
# 10  1930-URUGUAY              GROUP_STAGE           6-3 (3-1)
# 11  1930-URUGUAY              GROUP_STAGE           4-0 (1-0)
# 12  1930-URUGUAY              GROUP_STAGE           1-0 (1-0)
# 13  1930-URUGUAY              GROUP_STAGE           4-0 (4-0)
# 14  1930-URUGUAY              GROUP_STAGE           3-1 (2-1)
# 15  1930-URUGUAY                1/2_FINAL           6-1 (1-0)
# 16  1930-URUGUAY                1/2_FINAL           6-1 (3-1)
# 17  1930-URUGUAY                   _FINAL           4-2 (1-2)
# 18    1934-ITALY       PRELIMINARY-Europe           6-2 (4-0)
# 19    1934-ITALY       PRELIMINARY-Europe           0-2 (0-0)
# 20    1934-ITALY       PRELIMINARY-Europe           2-2 (0-0)
# 21    1934-ITALY       PRELIMINARY-Europe           1-2 (0-1)
# 22    1934-ITALY       PRELIMINARY-Europe          2-0 (w.o.)
# 23    1934-ITALY  PRELIMINARY-N/C.America           1-3 (0-1)
# 24    1934-ITALY  PRELIMINARY-N/C.America           1-1 (0-0)
# 25    1934-ITALY  PRELIMINARY-N/C.America           0-6 (0-3)
# 26    1934-ITALY       PRELIMINARY-Europe           4-4 (1-2)
# 27    1934-ITALY  PRELIMINARY-N/C.America           3-2 (3-1)
# 28    1934-ITALY       PRELIMINARY-Europe           9-0 (3-0)
# 29    1934-ITALY       PRELIMINARY-Europe           1-9 (1-5)
# 30    1934-ITALY  PRELIMINARY-N/C.America           5-0 (3-0)
# 31    1934-ITALY         PRELIMINARY-N.E.           7-1 (4-0)
# 32    1934-ITALY       PRELIMINARY-Europe           1-2 (1-2)
# 33    1934-ITALY  PRELIMINARY-N/C.America           4-1 (2-1)
# 34    1934-ITALY       PRELIMINARY-Europe           4-0 (2-0)
# 35    1934-ITALY       PRELIMINARY-Europe           1-4 (1-1)
# 36    1934-ITALY         PRELIMINARY-N.E.           1-4 (0-4)
# 37    1934-ITALY       PRELIMINARY-Europe           5-2 (1-1)
# 38    1934-ITALY       PRELIMINARY-Europe           1-6 (0-2)
# 39    1934-ITALY       PRELIMINARY-Europe           6-1 (3-0)
# 40    1934-ITALY       PRELIMINARY-Europe           4-1 (1-0)
# 41    1934-ITALY       PRELIMINARY-Europe           2-1 (1-0)
# 42    1934-ITALY       PRELIMINARY-Europe           2-4 (0-0)
# 43    1934-ITALY  PRELIMINARY-N/C.America           4-2 (2-1)
# 44    1934-ITALY                    FIRST           7-1 (3-0)
# 45    1934-ITALY                    FIRST  3-2 (1-1) (a.e.t.)
# 46    1934-ITALY                    FIRST           5-2 (1-2)
# 47    1934-ITALY                    FIRST           2-1 (0-1)
# 48    1934-ITALY                    FIRST           3-2 (2-1)
# 49    1934-ITALY                    FIRST           3-2 (1-1)
#
#                                   team1                                team2  \
# 0                                France                      Mexico (México)
# 1                                   USA                     Belgium (België)
# 2              Yugoslavia (Југославија)                      Brazil (Brasil)
# 3                     Romania (România)                          Peru (Perú)
# 4                             Argentina                               France
# 5                                 Chile                      Mexico (México)
# 6              Yugoslavia (Југославија)                              Bolivia
# 7                                   USA                             Paraguay
# 8                               Uruguay                          Peru (Perú)
# 9                                 Chile                               France
# 10                            Argentina                      Mexico (México)
# 11                      Brazil (Brasil)                              Bolivia
# 12                             Paraguay                     Belgium (België)
# 13                              Uruguay                    Romania (România)
# 14                            Argentina                                Chile
# 15                            Argentina                                  USA
# 16                              Uruguay             Yugoslavia (Југославија)
# 17                              Uruguay                            Argentina
# 18                     Sweden (Sverige)                      Estonia (Eesti)
# 19                  Lithuania (Lietuva)                     Sweden (Sverige)
# 20             Yugoslavia (Југославија)       Switzerland (Schweiz / Suisse)
# 21                      Poland (Polska)      Czechoslovakia (Československo)
# 22       Switzerland (Schweiz / Suisse)                    Romania (România)
# 23                        Haiti (Haïti)                                 Cuba
# 24                        Haiti (Haïti)                                 Cuba
# 25                        Haiti (Haïti)                                 Cuba
# 26  Irish Free State (Saorstát Éireann)                     Belgium (België)
# 27                      Mexico (México)                                 Cuba
# 28                       Spain (España)                             Portugal
# 29              Luxembourg (Lëtzebuerg)                Germany (Deutschland)
# 30                      Mexico (México)                                 Cuba
# 31                          Egypt (مصر)                   Palestine (فلسطين)
# 32                             Portugal                       Spain (España)
# 33                      Mexico (México)                                 Cuba
# 34                       Italy (Italia)                      Greece (Ελλάδα)
# 35                  Bulgaria (България)               Hungary (Magyarország)
# 36                   Palestine (فلسطين)                          Egypt (مصر)
# 37              Netherlands (Nederland)  Irish Free State (Saorstát Éireann)
# 38              Luxembourg (Lëtzebuerg)                               France
# 39                 Austria (Österreich)                  Bulgaria (България)
# 40               Hungary (Magyarország)                  Bulgaria (България)
# 41                    Romania (România)             Yugoslavia (Југославија)
# 42                     Belgium (België)              Netherlands (Nederland)
# 43                                  USA                      Mexico (México)
# 44                       Italy (Italia)                                  USA
# 45                 Austria (Österreich)                               France
# 46                Germany (Deutschland)                     Belgium (België)
# 47      Czechoslovakia (Československo)                    Romania (România)
# 48       Switzerland (Schweiz / Suisse)              Netherlands (Nederland)
# 49                     Sweden (Sverige)                            Argentina
#
#                                  url            venue  year  score_list
# 0      1930_URUGUAY_FS.htm#1-WC-30-I      Montevideo.  1930  [4-1, 3-0]
# 1     1930_URUGUAY_FS.htm#13-WC-30-I      Montevideo.  1930  [3-0, 2-0]
# 2      1930_URUGUAY_FS.htm#7-WC-30-I      Montevideo.  1930  [2-1, 2-0]
# 3     1930_URUGUAY_FS.htm#10-WC-30-I      Montevideo.  1930  [3-1, 1-0]
# 4      1930_URUGUAY_FS.htm#2-WC-30-I      Montevideo.  1930  [1-0, 0-0]
# 5      1930_URUGUAY_FS.htm#3-WC-30-I      Montevideo.  1930  [3-0, 1-0]
# 6      1930_URUGUAY_FS.htm#8-WC-30-I      Montevideo.  1930  [4-0, 0-0]
# 7     1930_URUGUAY_FS.htm#14-WC-30-I      Montevideo.  1930  [3-0, 2-0]
# 8     1930_URUGUAY_FS.htm#11-WC-30-I      Montevideo.  1930  [1-0, 0-0]
# 9      1930_URUGUAY_FS.htm#4-WC-30-I      Montevideo.  1930  [1-0, 0-0]
# 10     1930_URUGUAY_FS.htm#5-WC-30-I      Montevideo.  1930  [6-3, 3-1]
# 11     1930_URUGUAY_FS.htm#9-WC-30-I      Montevideo.  1930  [4-0, 1-0]
# 12    1930_URUGUAY_FS.htm#15-WC-30-I      Montevideo.  1930  [1-0, 1-0]
# 13    1930_URUGUAY_FS.htm#12-WC-30-I      Montevideo.  1930  [4-0, 4-0]
# 14     1930_URUGUAY_FS.htm#6-WC-30-I      Montevideo.  1930  [3-1, 2-1]
# 15   1930_URUGUAY_FS.htm#16-WC-30-II      Montevideo.  1930  [6-1, 1-0]
# 16   1930_URUGUAY_FS.htm#17-WC-30-II      Montevideo.  1930  [6-1, 3-1]
# 17  1930_URUGUAY_FS.htm#18-WC-30-III      Montevideo.  1930  [4-2, 1-2]
# 18                 1934_ITALY_PR.htm       Stockholm.  1933  [6-2, 4-0]
# 19                 1934_ITALY_PR.htm          Kaunas.  1933  [0-2, 0-0]
# 20                 1934_ITALY_PR.htm         Beograd.  1933  [2-2, 0-0]
# 21                 1934_ITALY_PR.htm        Warszawa.  1933  [1-2, 0-1]
# 22                 1934_ITALY_PR.htm            Bern.  1933       [2-0]
# 23                 1934_ITALY_PR.htm  Port-au-Prince.  1934  [1-3, 0-1]
# 24                 1934_ITALY_PR.htm  Port-au-Prince.  1934  [1-1, 0-0]
# 25                 1934_ITALY_PR.htm  Port-au-Prince.  1934  [0-6, 0-3]
# 26                 1934_ITALY_PR.htm          Dublin.  1934  [4-4, 1-2]
# 27                 1934_ITALY_PR.htm      México D.F.  1934  [3-2, 3-1]
# 28    1934_ITALY_PR_GD.htm#WC-34-I-1          Madrid.  1934  [9-0, 3-0]
# 29                 1934_ITALY_PR.htm      Luxembourg.  1934  [1-9, 1-5]
# 30                 1934_ITALY_PR.htm      México D.F.  1934  [5-0, 3-0]
# 31                 1934_ITALY_PR.htm           Cairo.  1934  [7-1, 4-0]
# 32    1934_ITALY_PR_GD.htm#WC-34-I-1          Lisboa.  1934  [1-2, 1-2]
# 33                 1934_ITALY_PR.htm      México D.F.  1934  [4-1, 2-1]
# 34                 1934_ITALY_PR.htm          Milano.  1934  [4-0, 2-0]
# 35                 1934_ITALY_PR.htm          Sofija.  1934  [1-4, 1-1]
# 36                 1934_ITALY_PR.htm       Jerusalem.  1934  [1-4, 0-4]
# 37                 1934_ITALY_PR.htm       Amsterdam.  1934  [5-2, 1-1]
# 38                 1934_ITALY_PR.htm      Luxembourg.  1934  [1-6, 0-2]
# 39                 1934_ITALY_PR.htm            Wien.  1934  [6-1, 3-0]
# 40                 1934_ITALY_PR.htm        Budapest.  1934  [4-1, 1-0]
# 41                 1934_ITALY_PR.htm       Bucureşti.  1934  [2-1, 1-0]
# 42                 1934_ITALY_PR.htm       Antwerpen.  1934  [2-4, 0-0]
# 43                 1934_ITALY_PR.htm            Roma.  1934  [4-2, 2-1]
# 44      1934_ITALY_FS.htm#20-WC-34-I            Roma.  1934  [7-1, 3-0]
# 45      1934_ITALY_FS.htm#19-WC-34-I          Torino.  1934  [3-2, 1-1]
# 46      1934_ITALY_FS.htm#21-WC-34-I         Firenze.  1934  [5-2, 1-2]
# 47      1934_ITALY_FS.htm#22-WC-34-I         Trieste.  1934  [2-1, 0-1]
# 48      1934_ITALY_FS.htm#23-WC-34-I          Milano.  1934  [3-2, 2-1]
# 49      1934_ITALY_FS.htm#24-WC-34-I         Bologna.  1934  [3-2, 1-1]

# %%
df_2010[['final_score','halftime_score']] = df_2010['score_list'].str.split(',', 1, expand=True)
df_2010['halftime_score'] = df_2010['halftime_score'].fillna("")
#df_2010[['home_result','away_result']] = df_2010['final_score'].str.split('-', expand=True)
df_2010.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[698], line 1
# ----> 1 df_2010[['final_score','halftime_score']] = df_2010['score_list'].str.split(',', 1, expand=True)
#       2 df_2010['halftime_score'] = df_2010['halftime_score'].fillna("")
#       3 #df_2010[['home_result','away_result']] = df_2010['final_score'].str.split('-', expand=True)
#
# File c:\Users\Admin\Documents\Ashley\A Simplon\Week 4 (15 dec - 19 dec)\Projet ETL Football\Brief-2-ETL-de-donn-es-footballistiques-Wickets-Sprinters-1\.venv\Lib\site-packages\pandas\core\strings\accessor.py:140, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
#     139     raise TypeError(msg)
# --> 140 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
df_2010[['final_score','halftime_score']] = df_2010['score_list'].str.extract(r'([^,]+),?(.*)')
df_2010.head()
# Out:
#         edition        round      score                     team1  \
# 0  1930-URUGUAY  GROUP_STAGE  4-1 (3-0)                    France
# 1  1930-URUGUAY  GROUP_STAGE  3-0 (2-0)                       USA
# 2  1930-URUGUAY  GROUP_STAGE  2-1 (2-0)  Yugoslavia (Југославија)
# 3  1930-URUGUAY  GROUP_STAGE  3-1 (1-0)         Romania (România)
# 4  1930-URUGUAY  GROUP_STAGE  1-0 (0-0)                 Argentina
#
#               team2                             url        venue  year  \
# 0   Mexico (México)   1930_URUGUAY_FS.htm#1-WC-30-I  Montevideo.  1930
# 1  Belgium (België)  1930_URUGUAY_FS.htm#13-WC-30-I  Montevideo.  1930
# 2   Brazil (Brasil)   1930_URUGUAY_FS.htm#7-WC-30-I  Montevideo.  1930
# 3       Peru (Perú)  1930_URUGUAY_FS.htm#10-WC-30-I  Montevideo.  1930
# 4            France   1930_URUGUAY_FS.htm#2-WC-30-I  Montevideo.  1930
#
#    score_list final_score halftime_score
# 0  [4-1, 3-0]         NaN            NaN
# 1  [3-0, 2-0]         NaN            NaN
# 2  [2-1, 2-0]         NaN            NaN
# 3  [3-1, 1-0]         NaN            NaN
# 4  [1-0, 0-0]         NaN            NaN

# %%
np.shape(df_2010)
# Out:
# (7299, 9)

# %%
#rename columns pour etre homogène avec les autres datasets
df_2010 = df_2010.rename(columns={'year': 'date', 'team1': 'home_team', 'team2' : 'away_team', 'venue' : 'city', 'round': 'stage'})

# %%
#home_team et away_team, garder que le nom de pays en Anglais
df_2010[['home_team','home_team_lanorig']] = df_2010['home_team'].str.split('(', expand=True)
df_2010[['away_team','away_team_lanorig']] = df_2010['away_team'].str.split('(', expand=True)
df_2010.head()
# Out:
#         edition        stage      score    home_team away_team  \
# 0  1930-URUGUAY  GROUP_STAGE  4-1 (3-0)       France   Mexico
# 1  1930-URUGUAY  GROUP_STAGE  3-0 (2-0)          USA  Belgium
# 2  1930-URUGUAY  GROUP_STAGE  2-1 (2-0)  Yugoslavia    Brazil
# 3  1930-URUGUAY  GROUP_STAGE  3-1 (1-0)     Romania      Peru
# 4  1930-URUGUAY  GROUP_STAGE  1-0 (0-0)    Argentina    France
#
#                               url         city  date score_list  \
# 0   1930_URUGUAY_FS.htm#1-WC-30-I  Montevideo.  1930         []
# 1  1930_URUGUAY_FS.htm#13-WC-30-I  Montevideo.  1930         []
# 2   1930_URUGUAY_FS.htm#7-WC-30-I  Montevideo.  1930         []
# 3  1930_URUGUAY_FS.htm#10-WC-30-I  Montevideo.  1930         []
# 4   1930_URUGUAY_FS.htm#2-WC-30-I  Montevideo.  1930         []
#
#   home_team_lanorig away_team_lanorig
# 0              None           México)
# 1              None           België)
# 2      Југославија)           Brasil)
# 3          România)             Perú)
# 4              None              None

# %%
#garder que l'année pour 'edition'
edition = df_2010['edition']
edition = edition[:4]

# %%
#supprimer '.' dans colonne 'city'
city = df_2010['city']
city = city.replace('.','')
df_2010.head()
# Out:
#         edition        stage      score    home_team away_team  \
# 0  1930-URUGUAY  GROUP_STAGE  4-1 (3-0)       France   Mexico
# 1  1930-URUGUAY  GROUP_STAGE  3-0 (2-0)          USA  Belgium
# 2  1930-URUGUAY  GROUP_STAGE  2-1 (2-0)  Yugoslavia    Brazil
# 3  1930-URUGUAY  GROUP_STAGE  3-1 (1-0)     Romania      Peru
# 4  1930-URUGUAY  GROUP_STAGE  1-0 (0-0)    Argentina    France
#
#                               url         city  date score_list  \
# 0   1930_URUGUAY_FS.htm#1-WC-30-I  Montevideo.  1930         []
# 1  1930_URUGUAY_FS.htm#13-WC-30-I  Montevideo.  1930         []
# 2   1930_URUGUAY_FS.htm#7-WC-30-I  Montevideo.  1930         []
# 3  1930_URUGUAY_FS.htm#10-WC-30-I  Montevideo.  1930         []
# 4   1930_URUGUAY_FS.htm#2-WC-30-I  Montevideo.  1930         []
#
#   home_team_lanorig away_team_lanorig
# 0              None           México)
# 1              None           België)
# 2      Југославија)           Brasil)
# 3          România)             Perú)
# 4              None              None

# %%
#garder que des colonnes nescessaires
df_2010[['date', 'home_team', 'away_team', 'home_result', 'away_result', 'stage', 'edition', 'city']].to_csv('matches_19302010.csv', index=False)
df_2010 = pd.read_csv('matches_19302010.csv',usecols=['date', 'home_team', 'away_team', 'home_result', 'away_result', 'stage', 'edition', 'city']) 
print(df_2010)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[606], line 2
#       1 #garder que des colonnes nescessaires
# ----> 2 df_2010[['date', 'home_team', 'away_team', 'home_result', 'away_result', 'stage', 'edition', 'city']].to_csv('matches_19302010.csv', index=False)
#       3 df_2010 = pd.read_csv('matches_19302010.csv',usecols=['date', 'home_team', 'away_team', 'home_result', 'away_result', 'stage', 'edition', 'city'])
#       4 print(df_2010)
#
# File c:\Users\Admin\Documents\Ashley\A Simplon\Week 4 (15 dec - 19 dec)\Projet ETL Football\Brief-2-ETL-de-donn-es-footballistiques-Wickets-Sprinters-1\.venv\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Admin\Documents\Ashley\A Simplon\Week 4 (15 dec - 19 dec)\Projet ETL Football\Brief-2-ETL-de-donn-es-footballistiques-Wickets-Sprinters-1\.venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Admin\Documents\Ashley\A Simplon\Week 4 (15 dec - 19 dec)\Projet ETL Football\Brief-2-ETL-de-donn-es-footballistiques-Wickets-Sprinters-1\.venv\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['home_result', 'away_result'] not in index"

# %%
df_2010['stage'].unique()
# Out:
# array(['GROUP_STAGE'], dtype=object)
